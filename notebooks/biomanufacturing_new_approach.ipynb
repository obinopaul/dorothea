# %% [markdown]
# >       Keep alive on Google Colab

# %%
#keep alive (right click 'inspect', then 'console', clear console and paste the below code)
function ConnectButton(){
    console.log("Connect pushed"); 
    document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click() 
}

var colab = setInterval(ConnectButton,600000);   #to connect for 10 mins

#clearInterval(connect)     #to clear the keep alive interval

# %% [markdown]
# >       Mount drive and Install Libraries

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive') 

#install libraries 
# !pip install -q -r '/content/drive/MyDrive/Colab Notebooks/requirements.txt'

# %% [markdown]
# <br>Table of Content:
# * [Import Libraries](#1)
# * [Load Data](#2)
# * [Data Preprocessing](#3)
# * [Selecting and Training the Model](#4)
#     * [Logistic Regression](#4a)
#     * [Support Vector Machines (SVM)](#4b)
#     * [Decision Tree](#4c)
# * [Model Optimization: Hyperparameter Tuning](#5)
# * [Feature Selection and Retraining Model](#6)
# * [Saving the Model](#7)

# %% [markdown]
# <a id="1"></a> <br>
# ## Import Libraries

# %%
# Data Analysis      
import os
import pandas as pd          # data analysis library for handling structured data  
import numpy as np           # mathematical library for working with numerical data
from pandas.plotting import parallel_coordinates 
from functions import *

# Visualization
import matplotlib.pyplot as plt     # data visualization library for creating graphs and charts
# %matplotlib inline
import seaborn as sns        # data visualization library based on matplotlib for creating more attractive visualizations
import missingno as msno    #visualize missing data

from joblib import load, dump
import optuna

# Ignore warnings
import warnings
warnings.filterwarnings("ignore") 

pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# <a id="2"></a> <br>
# ## Load Data

# %%
import pandas as pd
import numpy as np

def load_dorothea_data(data_filename, label_filename, nrows, ncols):
    # Initialize a zero matrix
    data_matrix = np.zeros((nrows, ncols), dtype=int)

    # Read the data file
    with open(data_filename, 'r') as file:
        for i, line in enumerate(file):
            # Convert line to integers and set the corresponding indices to 1
            indices = np.fromstring(line, dtype=int, sep=' ') - 1
            data_matrix[i, indices] = 1

    # Load labels
    labels = pd.read_csv(label_filename, header=None).values.flatten()

    return data_matrix, labels

# Specify the number of rows and columns
nrows, ncols = 800, 100000  # Adjust nrows for different datasets

# Load training data
train_data, train_labels = load_dorothea_data('DOROTHEA/dorothea_train.data', 'DOROTHEA/dorothea_train.labels', nrows, ncols)
train_data_df = pd.DataFrame(train_data, columns=["feature_" + str(i) for i in range(1, train_data.shape[1]+1)])

# Load validation data
valid_data, valid_labels = load_dorothea_data('DOROTHEA/dorothea_valid.data', 'DOROTHEA/dorothea_valid.labels', 350, ncols)
valid_data_df = pd.DataFrame(valid_data, columns=["feature_" + str(i) for i in range(1, valid_data.shape[1]+1)])

# %% [markdown]
# >>      Data Understanding

# %%
print(f"Train Features: {train_data.shape[0]} rows and {train_data.shape[1]} columns")
print(f"Train Labels: {train_labels.shape[0]} instances")
print(f"Validation Features: {valid_data.shape[0]} rows and {valid_data.shape[1]} columns")
print(f"Validation Labels: {valid_labels.shape[0]} instances")
# Out:
# Train Features: 800 rows and 100000 columns
# Train Labels: 800 instances
# Validation Features: 350 rows and 100000 columns
# Validation Labels: 350 instances

# %%
train_data_df.info()    # Train Dataset
print( )
valid_data_df.info()    # Validation Dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Columns: 100000 entries, feature_1 to feature_100000
# dtypes: int32(100000)
# memory usage: 305.2 MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Columns: 100000 entries, feature_1 to feature_100000
# dtypes: int32(100000)
# memory usage: 133.5 MB

# %% [markdown]
# <a id="3"></a> <br>
# ## Data Preprocessing

# %% [markdown]
# >       Data Cleaning: Check for missing values

# %%
# Check for missing values
missing_value_counts = train_data_df.isnull().sum()
if missing_value_counts.sum() == 0:
    print("No Missing Values")
else:
    print({col: missing for col, missing in missing_value_counts.items() if missing > 0})
# Out:
# No Missing Values

# %% [markdown]
# >       Data Transformation - Standardization

# %% [markdown]
# Since the Dorothea dataset consists of binary data (0s and 1s), the features are already on the same scale. Standardization would not be meaningful because the 0s and 1s represent the absence or presence of a feature, rather than a quantitative measurement.
#
# In addition, the dataset is sparse, meaning that most of the values are zero. Standardizing would shift the 0s away from zero, which would eliminate the sparsity of the dataset.

# %% [markdown]
# >       Data Imbalance

# %% [markdown]
# We could fix the data imbalance at this stage, or use a stratified fold cross validation method when building the model to account for the data imbalance
#
# The Stratified K-fold cross-validation ensures that each fold has an approximately equal distribution of target classes, making it suitable for imbalanced datasets.

# %%
from yellowbrick.target import ClassBalance 


classes = [-1, 1]
# Instantiate the visualizer
visualizer = ClassBalance(labels=classes)
visualizer.fit(train_labels, valid_labels)        # Fit the data to the visualizer (you can also use visualizer.fit(y))
visualizer.show()                       # Finalize and render the figure
# Out:
# <AxesSubplot: title={'center': 'Class Balance for 1,150 Instances'}, ylabel='support'>

# %% [markdown]
# <a id="4"></a> <br>
# ## Selecting and Training the Model

# %% [markdown]
# | Classification Algorithms | Characteristics |
# |---------------------------|-----------------|
# | Logistic Regression       | - Simple to understand and implement for binary data<br>- Useful to find relationships between features |
# | Support Vector Machine    | - Effective with high dimensional data<br>- Relatively computationally cheap |
# | Decision Tree             | - Breakdown of complex data into smaller sections<br>- Simple interpretability |

# %% [markdown]
# <a id="4a"></a> <br>
# ### Training a Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import make_scorer, roc_auc_score, confusion_matrix


def runLR_CV(data_X, data_y, C=1.0, penalty="l1"):
    model = LogisticRegression(C=C, penalty=penalty, solver='liblinear', max_iter=1000)
    
    # Prepare cross validation
    skf = StratifiedKFold(n_splits=10)
    auc_scores_train = []
    auc_scores_test = []
    
    for train_index, test_index in skf.split(data_X, data_y):
        # Split data into training and test sets for current fold
        train_X, test_X = data_X[train_index], data_X[test_index]
        train_y, test_y = data_y[train_index], data_y[test_index]
        
        # Fit the model
        model.fit(train_X, train_y)
        
        # Calculate predictions
        train_preds = model.predict_proba(train_X)[:, 1]
        test_preds = model.predict_proba(test_X)[:, 1]
        
        # Calculate ROC AUC and append to list
        auc_train = roc_auc_score(train_y, train_preds)
        auc_test = roc_auc_score(test_y, test_preds)
        auc_scores_train.append(auc_train)
        auc_scores_test.append(auc_test)
    
    # Calculate the average AUC scores across all folds
    avg_auc_train = sum(auc_scores_train) / len(auc_scores_train)
    avg_auc_test = sum(auc_scores_test) / len(auc_scores_test)
    print("Average Train AUC:", avg_auc_train)
    print("Average Test AUC:", avg_auc_test)
    
    return avg_auc_train, avg_auc_test, model

# Assuming train_X and train_y are your data and labels
avg_auc_train, avg_auc_test, log_model = runLR_CV(train_data, train_labels, C=1.0, penalty="l1")
# Out:
# Average Train AUC: 1.0
# Average Test AUC: 0.8787963415959992

# %%
# Performance Report - Logistic Regression

y_pred,ACC,PC,RC,FS,AP,roc_auc,gini = print_classification_performance2class_report(log_model,valid_data,valid_labels)
# Out:
# Accuracy: 93.14%
# Precision: 75.00%
# Sensitivity (Recall): 44.12%
# Specificity: 98.42%
# Fscore: 55.56%
# Average precision: 38.52%
# G-Mean: 65.89%
# ROC AUC: 80.09%

# %%
#Precision - Recall Curve
from yellowbrick.classifier import PrecisionRecallCurve

# Create the visualizer, fit, score, and show it
viz = PrecisionRecallCurve(log_model, per_class=True,
                            cmap="Set1", iso_f1_curves=True, 
                            micro=False)
viz.fit(train_data, train_labels)
viz.score(valid_data, valid_labels)
viz.show()
# Out:
# <AxesSubplot: title={'center': 'Precision-Recall Curve for LogisticRegression'}, xlabel='Recall', ylabel='Precision'>

# %%
train_sizes = np.linspace(0.1, 1.0, 5)
cv = 10

train_sizes, train_mean, train_std, test_mean, test_std  = cv_learning_curve(log_model, train_data, train_labels, cv, train_sizes)

# %% [markdown]
# <a id="4b"></a> <br>
# ### Training a Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC

### Running SVM
def runSVC_CV(data_X, data_y, C=1.0, kernels=["rbf", "linear", "poly"]):
    results = {}

    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

    for kernel_choice in kernels:
        model = SVC(C=C, kernel=kernel_choice, probability=True)
        auc_scores_train = []
        auc_scores_test = []

        for train_index, test_index in skf.split(data_X, data_y):
            train_X, test_X = data_X[train_index], data_X[test_index]
            train_y, test_y = data_y[train_index], data_y[test_index]
            
            model.fit(train_X, train_y)
            train_preds = model.predict_proba(train_X)[:, 1]
            test_preds = model.predict_proba(test_X)[:, 1]

            auc_train = roc_auc_score(train_y, train_preds)
            auc_test = roc_auc_score(test_y, test_preds)
            auc_scores_train.append(auc_train)
            auc_scores_test.append(auc_test)

        avg_auc_train = np.mean(auc_scores_train)
        avg_auc_test = np.mean(auc_scores_test)
        print(f"Kernel: {kernel_choice} | Average Train AUC: {avg_auc_train:.4f} | Average Test AUC: {avg_auc_test:.4f}")

        results[kernel_choice] = {
            'avg_auc_train': avg_auc_train, 
            'avg_auc_test': avg_auc_test, 
            'model': model
        }
    
    return results

# Example usage:
results = runSVC_CV(train_data, train_labels, C=1.0)
# Out:
# Kernel: rbf | Average Train AUC: 1.0000 | Average Test AUC: 0.9126
# Kernel: linear | Average Train AUC: 1.0000 | Average Test AUC: 0.9402
# Kernel: poly | Average Train AUC: 1.0000 | Average Test AUC: 0.9371

# %%
# Separate variables for each kernel model
rbf_model = results['rbf']['model']
linear_model = results['linear']['model']
poly_model = results['poly']['model']

# %%
# Performance Report - Support Vector Machine (SVM) with rbf kernel

y_pred,ACC,PC,RC,FS,AP,roc_auc,gini = print_classification_performance2class_report(rbf_model,valid_data,valid_labels)
# Out:
# Accuracy: 90.29%
# Precision: nan%
# Sensitivity (Recall): 0.00%
# Specificity: 100.00%
# Fscore: nan%
# Average precision: 9.71%
# G-Mean: 0.00%
# ROC AUC: 91.62%

# %%
# Performance Report - Support Vector Machine (SVM) - linear kernel

y_pred,ACC,PC,RC,FS,AP,roc_auc,gini = print_classification_performance2class_report(linear_model,valid_data,valid_labels)
# Out:
# Accuracy: 92.29%
# Precision: 88.89%
# Sensitivity (Recall): 23.53%
# Specificity: 99.68%
# Fscore: 37.21%
# Average precision: 28.34%
# G-Mean: 48.43%
# ROC AUC: 90.49%

# %%
# Performance Report - Support Vector Machine (SVM) - polynomial kernel

y_pred,ACC,PC,RC,FS,AP,roc_auc,gini = print_classification_performance2class_report(poly_model,valid_data,valid_labels)
# Out:
# Accuracy: 90.29%
# Precision: nan%
# Sensitivity (Recall): 0.00%
# Specificity: 100.00%
# Fscore: nan%
# Average precision: 9.71%
# G-Mean: 0.00%
# ROC AUC: 91.70%

# %% [markdown]
# <a id="4c"></a> <br>
# ### Training a Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier


def runDT_CV(data_X, data_y, criterion="gini", depth=None, min_split=2, min_leaf=1):
    results = {}

    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    auc_scores_train = []
    auc_scores_test = []

    for train_index, test_index in skf.split(data_X, data_y):
        train_X, test_X = data_X[train_index], data_X[test_index]
        train_y, test_y = data_y[train_index], data_y[test_index]

        model = DecisionTreeClassifier(
            criterion=criterion,
            max_depth=depth,
            min_samples_split=min_split,
            min_samples_leaf=min_leaf,
        )
        model.fit(train_X, train_y)
        train_preds = model.predict_proba(train_X)[:, 1]
        test_preds = model.predict_proba(test_X)[:, 1]

        auc_train = roc_auc_score(train_y, train_preds)
        auc_test = roc_auc_score(test_y, test_preds)
        auc_scores_train.append(auc_train)
        auc_scores_test.append(auc_test)

    avg_auc_train = np.mean(auc_scores_train)
    avg_auc_test = np.mean(auc_scores_test)
    print(f"Average Train AUC: {avg_auc_train:.4f} | Average Test AUC: {avg_auc_test:.4f}")

    results = {
        'avg_auc_train': avg_auc_train, 
        'avg_auc_test': avg_auc_test, 
        'model': model
    }
    
    return results

results = runDT_CV(train_data, train_labels, criterion="gini", depth=None, min_split=2, min_leaf=1) 
dt_model = results['model']
# Out:
# Average Train AUC: 1.0000 | Average Test AUC: 0.7519

# %%
# Performance Report - Decision Tree Model

y_pred,ACC,PC,RC,FS,AP,roc_auc,gini = print_classification_performance2class_report(dt_model,valid_data,valid_labels)
# Out:
# Accuracy: 92.29%
# Precision: 60.61%
# Sensitivity (Recall): 58.82%
# Specificity: 95.89%
# Fscore: 59.70%
# Average precision: 39.65%
# G-Mean: 75.10%
# ROC AUC: 77.35%

# %%
#Precision - Recall Curve
from yellowbrick.classifier import PrecisionRecallCurve

# Create the visualizer, fit, score, and show it
viz = PrecisionRecallCurve(dt_model, per_class=True,
                            cmap="Set1", iso_f1_curves=True, 
                            micro=False)
viz.fit(train_data, train_labels)
viz.score(valid_data, valid_labels)
viz.show()
# Out:
# <AxesSubplot: title={'center': 'Precision-Recall Curve for DecisionTreeClassifier'}, xlabel='Recall', ylabel='Precision'>

# %%
train_sizes = np.linspace(0.1, 1.0, 5)
cv = 10

train_sizes, train_mean, train_std, test_mean, test_std  = cv_learning_curve(dt_model, train_data, train_labels, cv, train_sizes)

# %% [markdown]
# >       Save the Model

# %%
from joblib import dump, load

# Save the model to a file
dump(log_model, 'models/initial_model/logistic_regression_model.joblib')
dump(rbf_model, 'models/initial_model/support_vector_rbf.joblib')
dump(linear_model, 'models/initial_model/support_vector_linear.joblib')
dump(poly_model, 'models/initial_model/support_vector_poly.joblib')
dump(dt_model, 'models/initial_model/decision_tree_model.joblib')
# Out:
# ['models/initial_model/decision_tree_model.joblib']

# %% [markdown]
# <a id="5"></a> <br>
# ## Model Optimization: Hyperparameter Tuning

# %% [markdown]
# >       Logistic Regression - Hyperparameter Optimization

# %%
from sklearn.linear_model import LogisticRegression

LogisticRegression().get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
#Automatic Hyperparameter Optimization using Optuna

import optuna 
import logging


# Set the logging level for Optuna to WARNING
# logging.getLogger('optuna').setLevel(logging.WARNING) 

# Define your objective function
def objective(trial):
    # Define the search space for the key hyperparameters
    C = trial.suggest_loguniform('C', 0.1, 10)
    solver = trial.suggest_categorical('solver', ['liblinear', 'saga'])
    # penalty = trial.suggest_categorical('penalty', ['l1', 'l2'])
    penalty = 'l2' 
    max_iter = trial.suggest_int('max_iter', 100, 1000)
        
    # Create the Logistic Regression model with the adjusted solver
    model = LogisticRegression(C=C, penalty=penalty, solver=solver, max_iter=max_iter)

    # Perform cross-validation and compute the average AUC score
    scores = cross_val_score(model, train_data, train_labels, scoring='roc_auc', n_jobs=-1, cv=10)
    avg_auc_test = np.mean(scores)
  
    return avg_auc_test

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

trial = study.best_trial

print('Accuracy: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# [I 2023-12-05 11:41:45,671] A new study created in memory with name: no-name-7a146dd0-e339-4c9d-a0f9-943c5319b2bf
# [I 2023-12-05 12:20:57,064] Trial 0 finished with value: 0.917552049358556 and parameters: {'C': 6.277306333572985, 'solver': 'saga', 'max_iter': 184}. Best is trial 0 with value: 0.917552049358556.

# %%
# study.best_params

# %%
# Extracting the best hyperparameters
best_hyperparams = study.best_trial.params

best_C_log = best_hyperparams['C']
best_penalty = best_hyperparams['penalty']
best_solver = best_hyperparams['solver']
best_max_iter = best_hyperparams['max_iter']

print('Best C (log): {}'.format(best_C_log))
print('Best penalty: {}'.format(best_penalty))
print('Best solver: {}'.format(best_solver))
print('Best max iter: {}'.format(best_max_iter))


log_tuned_model = LogisticRegression(C=best_C_log, penalty=best_penalty, solver=best_solver, max_iter=best_max_iter)

log_tuned_model.fit(train_data, train_labels)


dump(log_tuned_model, 'models/tuned_model/tuned_logistic_regression.joblib')

# %%
y_pred,ACC,PC,RC,FS,AP,roc_auc,gini = print_classification_performance2class_report(log_tuned_model,valid_data,valid_labels)

# %% [markdown]
# >       Support Vector Machines (SVC) - Hyperparameter Optimization

# %%
from sklearn.svm import SVC

SVC().get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
# Set the logging level for Optuna to WARNING
# logging.getLogger('optuna').setLevel(logging.WARNING) 

def objective(trial):
    # Define the hyperparameters' search space
    C = trial.suggest_loguniform('C', 1e-4, 1e4)
    kernel = trial.suggest_categorical('kernel', ['rbf', 'poly'])
    gamma = trial.suggest_categorical('gamma', ['scale', 'auto'])
    degree = trial.suggest_int('degree', 1, 5) if kernel == 'poly' else 3  # degree is only used for 'poly' kernel

    # Create the SVM model
    model = SVC(C=C, kernel=kernel, gamma=gamma, degree=degree, probability=True)

    # Perform cross-validation and compute the average AUC score
    scores = cross_val_score(model, train_data, train_labels, scoring='roc_auc', n_jobs=-1, cv=10)
    avg_auc_test = np.mean(scores)

    return avg_auc_test

# Create and run the study
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Best hyperparameters
best_hyperparams = study.best_trial.params
# print('Best Hyperparameters:', best_hyperparams)
# Out:
# [I 2023-12-05 13:42:28,833] A new study created in memory with name: no-name-84788ef9-1419-47de-a52a-2c692a404bbf
# [I 2023-12-05 13:49:26,910] Trial 0 finished with value: 0.8457477168949772 and parameters: {'C': 0.00021872972894263523, 'kernel': 'poly', 'gamma': 'scale', 'degree': 5}. Best is trial 0 with value: 0.8457477168949772.
# [I 2023-12-05 13:56:48,122] Trial 1 finished with value: 0.8630296667753861 and parameters: {'C': 0.000174377464488212, 'kernel': 'poly', 'gamma': 'scale', 'degree': 4}. Best is trial 1 with value: 0.8630296667753861.
# [I 2023-12-05 14:27:10,726] Trial 2 finished with value: 0.9446917808219177 and parameters: {'C': 1720.4365921177603, 'kernel': 'poly', 'gamma': 'scale', 'degree': 1}. Best is trial 2 with value: 0.9446917808219177.
# [I 2023-12-05 14:34:22,162] Trial 3 finished with value: 0.8029269270493586 and parameters: {'C': 0.0008369939976957247, 'kernel': 'poly', 'gamma': 'auto', 'degree': 4}. Best is trial 2 with value: 0.9446917808219177.
# [I 2023-12-05 15:17:36,448] Trial 4 finished with value: 0.9230695531637311 and parameters: {'C': 270.3130792670475, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 2 with value: 0.9446917808219177.
# [I 2023-12-05 15:26:31,478] Trial 5 finished with value: 0.8873946781909112 and parameters: {'C': 0.0005011410302290157, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 2 with value: 0.9446917808219177.
# [I 2023-12-05 16:06:23,936] Trial 6 finished with value: 0.915184686888454 and parameters: {'C': 25.450779449510406, 'kernel': 'poly', 'gamma': 'scale', 'degree': 3}. Best is trial 2 with value: 0.9446917808219177.
# [I 2023-12-05 16:46:18,406] Trial 7 finished with value: 0.9007725864318331 and parameters: {'C': 1.1266087100155013, 'kernel': 'poly', 'gamma': 'scale', 'degree': 4}. Best is trial 2 with value: 0.9446917808219177.
# [I 2023-12-05 17:29:20,167] Trial 8 finished with value: 0.9114756604696673 and parameters: {'C': 0.05838142162762404, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 2 with value: 0.9446917808219177.
# [I 2023-12-05 18:11:48,936] Trial 9 finished with value: 0.9511816427484237 and parameters: {'C': 47.17287146991738, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 9 with value: 0.9511816427484237.
# [I 2023-12-05 18:53:31,715] Trial 10 finished with value: 0.9468413649706457 and parameters: {'C': 9308.723106382029, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 9 with value: 0.9511816427484237.
# [I 2023-12-05 19:19:45,060] Trial 11 finished with value: 0.9468413649706457 and parameters: {'C': 8946.132670650135, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 9 with value: 0.9511816427484237.
# [I 2023-12-05 19:57:10,456] Trial 12 finished with value: 0.9513331702544031 and parameters: {'C': 67.03524704519934, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 12 with value: 0.9513331702544031.

# %%
# Best hyperparameters obtained from Optuna
# best_C_svm = best_hyperparams['C']
# best_kernel = best_hyperparams['kernel']
# best_gamma = best_hyperparams['gamma']
# best_degree = best_hyperparams['degree']


best_C_svm = 67.04
best_kernel = 'rbf'
best_gamma = 'auto'


print('Best C (svm): {}'.format(best_C_svm))
print('Best kernel: {}'.format(best_kernel))
print('Best gamma: {}'.format(best_gamma))
print('Best degree: {}'.format(best_degree))

# tuned_svm_model = SVC(C=best_C_svm, kernel=best_kernel, gamma=best_gamma, degree = best_degree, probability=True)
tuned_svm_model = SVC(C=best_C_svm, kernel=best_kernel, gamma=best_gamma, probability=True)
tuned_svm_model.fit(train_data, train_labels)

dump(tuned_svm_model, 'models/tuned_model/tuned_support_vector.joblib')

# %%
y_pred,ACC,PC,RC,FS,AP,roc_auc,gini = print_classification_performance2class_report(tuned_svm_model,valid_data,valid_labels)

# %% [markdown]
# >       Decision Trees - Hyperparameter Optimization

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
# Set the logging level for Optuna to WARNING
# logging.getLogger('optuna').setLevel(logging.WARNING) 
import optuna
from sklearn.model_selection import cross_val_score

def objective(trial):
    # Define the hyperparameters' search space
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
    max_depth = trial.suggest_int('max_depth', 1, 32)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)

    # Create the Decision Tree model with suggested hyperparameters
    model = DecisionTreeClassifier(
        criterion=criterion, 
        max_depth=max_depth, 
        min_samples_split=min_samples_split, 
        min_samples_leaf=min_samples_leaf
    )

    # Perform cross-validation and compute the average AUC score
    scores = cross_val_score(model, train_data, train_labels, scoring='roc_auc', n_jobs=-1, cv=10)
    avg_auc_test = np.mean(scores)

    return avg_auc_test


# Create and run the study
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100) 

# Best hyperparameters
best_hyperparams = study.best_trial.params
# print('Best Hyperparameters:', best_hyperparams)
# Out:
# [I 2023-12-05 08:09:15,789] A new study created in memory with name: no-name-4e161133-d0e5-4c9e-8bf8-a1e0abb730c6
# [I 2023-12-05 08:12:42,953] Trial 0 finished with value: 0.7316388413242008 and parameters: {'criterion': 'gini', 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 18}. Best is trial 0 with value: 0.7316388413242008.
# [I 2023-12-05 08:13:25,960] Trial 1 finished with value: 0.798881380463144 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 8}. Best is trial 1 with value: 0.798881380463144.
# [I 2023-12-05 08:14:06,355] Trial 2 finished with value: 0.715470924385736 and parameters: {'criterion': 'gini', 'max_depth': 28, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 1 with value: 0.798881380463144.
# [I 2023-12-05 08:15:05,535] Trial 3 finished with value: 0.7609412372254838 and parameters: {'criterion': 'gini', 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.798881380463144.
# [I 2023-12-05 08:15:44,504] Trial 4 finished with value: 0.7518144229723853 and parameters: {'criterion': 'entropy', 'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 13}. Best is trial 1 with value: 0.798881380463144.
# [I 2023-12-05 08:16:23,716] Trial 5 finished with value: 0.7650515057621222 and parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 10}. Best is trial 1 with value: 0.798881380463144.
# [I 2023-12-05 08:16:32,353] Trial 6 finished with value: 0.7362293433355076 and parameters: {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 16, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.798881380463144.
# [I 2023-12-05 08:17:17,388] Trial 7 finished with value: 0.7837079052511415 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 19, 'min_samples_leaf': 9}. Best is trial 1 with value: 0.798881380463144.
# [I 2023-12-05 08:17:31,858] Trial 8 finished with value: 0.7482953155577299 and parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_split': 14, 'min_samples_leaf': 7}. Best is trial 1 with value: 0.798881380463144.
# [I 2023-12-05 08:18:13,258] Trial 9 finished with value: 0.7166043229506414 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 20}. Best is trial 1 with value: 0.798881380463144.
# [I 2023-12-05 08:18:57,289] Trial 10 finished with value: 0.7598115758860622 and parameters: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 14}. Best is trial 1 with value: 0.798881380463144.
# [I 2023-12-05 08:19:41,399] Trial 11 finished with value: 0.7783247716894977 and parameters: {'criterion': 'entropy', 'max_depth': 11, 'min_samples_split': 20, 'min_samples_leaf': 9}. Best is trial 1 with value: 0.798881380463144.
# [I 2023-12-05 08:20:29,264] Trial 12 finished with value: 0.8110669439008479 and parameters: {'criterion': 'gini', 'max_depth': 13, 'min_samples_split': 16, 'min_samples_leaf': 7}. Best is trial 12 with value: 0.8110669439008479.
# [I 2023-12-05 08:21:18,044] Trial 13 finished with value: 0.8001950152207001 and parameters: {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 12, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.8110669439008479.
# [I 2023-12-05 08:22:01,971] Trial 14 finished with value: 0.8175089013916068 and parameters: {'criterion': 'entropy', 'max_depth': 18, 'min_samples_split': 13, 'min_samples_leaf': 5}. Best is trial 14 with value: 0.8175089013916068.
# [I 2023-12-05 08:22:50,956] Trial 15 finished with value: 0.737185053816047 and parameters: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 17, 'min_samples_leaf': 1}. Best is trial 14 with value: 0.8175089013916068.
# [I 2023-12-05 08:23:35,469] Trial 16 finished with value: 0.8143412630463145 and parameters: {'criterion': 'entropy', 'max_depth': 32, 'min_samples_split': 13, 'min_samples_leaf': 5}. Best is trial 14 with value: 0.8175089013916068.
# [I 2023-12-05 08:24:20,869] Trial 17 finished with value: 0.7976029095999129 and parameters: {'criterion': 'entropy', 'max_depth': 32, 'min_samples_split': 12, 'min_samples_leaf': 4}. Best is trial 14 with value: 0.8175089013916068.
# [I 2023-12-05 08:25:06,594] Trial 18 finished with value: 0.7599955493041965 and parameters: {'criterion': 'entropy', 'max_depth': 32, 'min_samples_split': 14, 'min_samples_leaf': 12}. Best is trial 14 with value: 0.8175089013916068.
# [I 2023-12-05 08:25:55,563] Trial 19 finished with value: 0.7791483202870189 and parameters: {'criterion': 'entropy', 'max_depth': 23, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 14 with value: 0.8175089013916068.
# [I 2023-12-05 08:26:46,491] Trial 20 finished with value: 0.798566943900848 and parameters: {'criterion': 'entropy', 'max_depth': 28, 'min_samples_split': 12, 'min_samples_leaf': 6}. Best is trial 14 with value: 0.8175089013916068.
# [I 2023-12-05 08:27:35,985] Trial 21 finished with value: 0.7940530550119591 and parameters: {'criterion': 'entropy', 'max_depth': 12, 'min_samples_split': 15, 'min_samples_leaf': 6}. Best is trial 14 with value: 0.8175089013916068.
# [I 2023-12-05 08:28:32,102] Trial 22 finished with value: 0.7657627677212437 and parameters: {'criterion': 'entropy', 'max_depth': 13, 'min_samples_split': 17, 'min_samples_leaf': 2}. Best is trial 14 with value: 0.8175089013916068.
# [I 2023-12-05 08:29:24,208] Trial 23 finished with value: 0.793465121493803 and parameters: {'criterion': 'entropy', 'max_depth': 19, 'min_samples_split': 18, 'min_samples_leaf': 7}. Best is trial 14 with value: 0.8175089013916068.
# [I 2023-12-05 08:30:20,324] Trial 24 finished with value: 0.8367398143618179 and parameters: {'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 13, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:31:07,966] Trial 25 finished with value: 0.7565289329202001 and parameters: {'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 13, 'min_samples_leaf': 3}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:31:45,351] Trial 26 finished with value: 0.779726231245923 and parameters: {'criterion': 'entropy', 'max_depth': 26, 'min_samples_split': 10, 'min_samples_leaf': 11}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:32:25,665] Trial 27 finished with value: 0.7609774203631224 and parameters: {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 11, 'min_samples_leaf': 15}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:33:19,122] Trial 28 finished with value: 0.8063935434333551 and parameters: {'criterion': 'entropy', 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:34:11,973] Trial 29 finished with value: 0.7727095904000869 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 4, 'min_samples_leaf': 16}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:35:05,824] Trial 30 finished with value: 0.794404014459665 and parameters: {'criterion': 'entropy', 'max_depth': 25, 'min_samples_split': 13, 'min_samples_leaf': 3}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:35:51,530] Trial 31 finished with value: 0.7996267870732768 and parameters: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 16, 'min_samples_leaf': 7}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:36:44,456] Trial 32 finished with value: 0.7996188030006522 and parameters: {'criterion': 'gini', 'max_depth': 24, 'min_samples_split': 15, 'min_samples_leaf': 8}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:37:39,224] Trial 33 finished with value: 0.7734750421287236 and parameters: {'criterion': 'gini', 'max_depth': 17, 'min_samples_split': 11, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:38:22,632] Trial 34 finished with value: 0.7725563641552511 and parameters: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 15, 'min_samples_leaf': 8}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:39:14,385] Trial 35 finished with value: 0.8136315299521636 and parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 6}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:40:04,291] Trial 36 finished with value: 0.7770836730811046 and parameters: {'criterion': 'entropy', 'max_depth': 28, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:40:28,723] Trial 37 finished with value: 0.6994237877799521 and parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:41:14,146] Trial 38 finished with value: 0.7563678924766253 and parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 10}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:41:58,602] Trial 39 finished with value: 0.8084799344966296 and parameters: {'criterion': 'entropy', 'max_depth': 30, 'min_samples_split': 12, 'min_samples_leaf': 6}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:42:28,284] Trial 40 finished with value: 0.7004654544466188 and parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:43:15,668] Trial 41 finished with value: 0.7979047754946726 and parameters: {'criterion': 'gini', 'max_depth': 13, 'min_samples_split': 14, 'min_samples_leaf': 8}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:44:02,740] Trial 42 finished with value: 0.7998530590889323 and parameters: {'criterion': 'gini', 'max_depth': 14, 'min_samples_split': 16, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:44:42,326] Trial 43 finished with value: 0.7649015071211133 and parameters: {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 18, 'min_samples_leaf': 9}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:45:29,178] Trial 44 finished with value: 0.8033127106436181 and parameters: {'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 13, 'min_samples_leaf': 6}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:46:14,708] Trial 45 finished with value: 0.780133249075886 and parameters: {'criterion': 'gini', 'max_depth': 18, 'min_samples_split': 15, 'min_samples_leaf': 4}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:46:47,042] Trial 46 finished with value: 0.8061966595999129 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 7}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:47:33,967] Trial 47 finished with value: 0.7796108868775822 and parameters: {'criterion': 'gini', 'max_depth': 16, 'min_samples_split': 11, 'min_samples_leaf': 4}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:48:01,935] Trial 48 finished with value: 0.7766435298434442 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 11}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:48:41,910] Trial 49 finished with value: 0.7261177701674277 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 2}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:49:35,267] Trial 50 finished with value: 0.7621899801587302 and parameters: {'criterion': 'gini', 'max_depth': 18, 'min_samples_split': 19, 'min_samples_leaf': 9}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:50:29,681] Trial 51 finished with value: 0.8042264622744074 and parameters: {'criterion': 'entropy', 'max_depth': 29, 'min_samples_split': 12, 'min_samples_leaf': 6}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:51:18,315] Trial 52 finished with value: 0.8085952788649706 and parameters: {'criterion': 'entropy', 'max_depth': 30, 'min_samples_split': 14, 'min_samples_leaf': 6}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:52:20,231] Trial 53 finished with value: 0.8323458564361816 and parameters: {'criterion': 'entropy', 'max_depth': 31, 'min_samples_split': 14, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:53:14,965] Trial 54 finished with value: 0.8036716541639486 and parameters: {'criterion': 'entropy', 'max_depth': 32, 'min_samples_split': 16, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:54:06,797] Trial 55 finished with value: 0.7936169887475539 and parameters: {'criterion': 'entropy', 'max_depth': 26, 'min_samples_split': 13, 'min_samples_leaf': 7}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:55:03,931] Trial 56 finished with value: 0.7906146376929767 and parameters: {'criterion': 'entropy', 'max_depth': 31, 'min_samples_split': 15, 'min_samples_leaf': 3}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:55:50,053] Trial 57 finished with value: 0.7981031881930855 and parameters: {'criterion': 'entropy', 'max_depth': 27, 'min_samples_split': 14, 'min_samples_leaf': 4}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:56:27,590] Trial 58 finished with value: 0.7930993830180475 and parameters: {'criterion': 'entropy', 'max_depth': 23, 'min_samples_split': 10, 'min_samples_leaf': 19}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:57:13,968] Trial 59 finished with value: 0.7970686562296151 and parameters: {'criterion': 'entropy', 'max_depth': 12, 'min_samples_split': 13, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:57:59,176] Trial 60 finished with value: 0.7961686643835616 and parameters: {'criterion': 'gini', 'max_depth': 14, 'min_samples_split': 16, 'min_samples_leaf': 8}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:58:42,739] Trial 61 finished with value: 0.8081581933572517 and parameters: {'criterion': 'entropy', 'max_depth': 30, 'min_samples_split': 14, 'min_samples_leaf': 6}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 08:59:23,950] Trial 62 finished with value: 0.799211445422918 and parameters: {'criterion': 'entropy', 'max_depth': 31, 'min_samples_split': 14, 'min_samples_leaf': 7}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:00:12,351] Trial 63 finished with value: 0.7782551233963906 and parameters: {'criterion': 'entropy', 'max_depth': 29, 'min_samples_split': 15, 'min_samples_leaf': 3}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:00:55,377] Trial 64 finished with value: 0.8031390995325071 and parameters: {'criterion': 'entropy', 'max_depth': 31, 'min_samples_split': 17, 'min_samples_leaf': 6}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:01:40,372] Trial 65 finished with value: 0.7776140193520331 and parameters: {'criterion': 'entropy', 'max_depth': 29, 'min_samples_split': 12, 'min_samples_leaf': 4}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:02:24,775] Trial 66 finished with value: 0.813145011143727 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 13, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:03:10,082] Trial 67 finished with value: 0.8236085630028267 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 11, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:03:54,826] Trial 68 finished with value: 0.8260185638182213 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 11, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:04:40,229] Trial 69 finished with value: 0.7404051831919982 and parameters: {'criterion': 'entropy', 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:05:29,434] Trial 70 finished with value: 0.7839222860948032 and parameters: {'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 11, 'min_samples_leaf': 2}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:06:21,060] Trial 71 finished with value: 0.8173147355403347 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 11, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:07:05,191] Trial 72 finished with value: 0.7743103120243531 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:07:49,957] Trial 73 finished with value: 0.78221539329202 and parameters: {'criterion': 'entropy', 'max_depth': 23, 'min_samples_split': 11, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:08:34,671] Trial 74 finished with value: 0.8139483447488584 and parameters: {'criterion': 'entropy', 'max_depth': 19, 'min_samples_split': 12, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:09:20,923] Trial 75 finished with value: 0.7626353894868451 and parameters: {'criterion': 'entropy', 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:10:04,302] Trial 76 finished with value: 0.8213105090780605 and parameters: {'criterion': 'entropy', 'max_depth': 24, 'min_samples_split': 12, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:10:39,191] Trial 77 finished with value: 0.793091398945423 and parameters: {'criterion': 'entropy', 'max_depth': 24, 'min_samples_split': 10, 'min_samples_leaf': 17}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:11:26,462] Trial 78 finished with value: 0.7317715128288758 and parameters: {'criterion': 'entropy', 'max_depth': 25, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:12:08,792] Trial 79 finished with value: 0.8021711581322026 and parameters: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 7}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:12:52,521] Trial 80 finished with value: 0.8297374429223744 and parameters: {'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 12, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:13:37,141] Trial 81 finished with value: 0.8013926261143727 and parameters: {'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 12, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:14:16,055] Trial 82 finished with value: 0.7456512285279409 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 11, 'min_samples_leaf': 13}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:15:02,283] Trial 83 finished with value: 0.7835815190802349 and parameters: {'criterion': 'entropy', 'max_depth': 24, 'min_samples_split': 12, 'min_samples_leaf': 4}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:15:46,166] Trial 84 finished with value: 0.8123953576864537 and parameters: {'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 13, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:16:27,925] Trial 85 finished with value: 0.814210630028267 and parameters: {'criterion': 'entropy', 'max_depth': 25, 'min_samples_split': 10, 'min_samples_leaf': 6}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:17:14,273] Trial 86 finished with value: 0.7807252595672974 and parameters: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 2}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:17:58,215] Trial 87 finished with value: 0.7962578481735159 and parameters: {'criterion': 'entropy', 'max_depth': 18, 'min_samples_split': 12, 'min_samples_leaf': 4}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:18:47,269] Trial 88 finished with value: 0.8044190992607089 and parameters: {'criterion': 'entropy', 'max_depth': 23, 'min_samples_split': 13, 'min_samples_leaf': 6}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:19:29,210] Trial 89 finished with value: 0.7741268482278756 and parameters: {'criterion': 'entropy', 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 8}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:20:15,372] Trial 90 finished with value: 0.8038692174929333 and parameters: {'criterion': 'entropy', 'max_depth': 27, 'min_samples_split': 12, 'min_samples_leaf': 7}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:21:19,107] Trial 91 finished with value: 0.8099236926505762 and parameters: {'criterion': 'entropy', 'max_depth': 25, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:22:05,303] Trial 92 finished with value: 0.7930981939008481 and parameters: {'criterion': 'entropy', 'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 6}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:22:52,984] Trial 93 finished with value: 0.7819466528049576 and parameters: {'criterion': 'entropy', 'max_depth': 24, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:23:36,256] Trial 94 finished with value: 0.8032228473581213 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_split': 11, 'min_samples_leaf': 6}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:24:23,499] Trial 95 finished with value: 0.7722004783648619 and parameters: {'criterion': 'entropy', 'max_depth': 16, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:25:11,203] Trial 96 finished with value: 0.8234680772994128 and parameters: {'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:25:57,710] Trial 97 finished with value: 0.8066193058273537 and parameters: {'criterion': 'entropy', 'max_depth': 22, 'min_samples_split': 12, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:26:43,791] Trial 98 finished with value: 0.8317050921395955 and parameters: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 14, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.
# [I 2023-12-05 09:27:28,397] Trial 99 finished with value: 0.8045587355946944 and parameters: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 14, 'min_samples_leaf': 5}. Best is trial 24 with value: 0.8367398143618179.

# %%
from joblib import dump, load

best_criterion = best_hyperparams['criterion']
best_max_depth = best_hyperparams['max_depth']
best_min_samples_split = best_hyperparams['min_samples_split']
best_min_samples_leaf = best_hyperparams['min_samples_leaf']

print("Best Criterion: {}".format(best_criterion))
print("Best max depth: {}".format(best_max_depth))
print("Best min samples split: {}".format(best_min_samples_split))
print("Best min samples leaf: {}".format(best_min_samples_leaf))


# Create the Decision Tree model with the best hyperparameters
tuned_dt_model = DecisionTreeClassifier(
    criterion=best_criterion,
    max_depth=best_max_depth,
    min_samples_split=best_min_samples_split,
    min_samples_leaf=best_min_samples_leaf
)

# Train the model using the entire dataset
tuned_dt_model.fit(train_data, train_labels)


dump(tuned_dt_model, 'models/tuned_model/tuned_decision_tree.joblib')
# Out:
# Best Criterion: entropy
# Best max depth: 22
# Best min samples split: 13
# Best min samples leaf: 5
# ['models/tuned_model/tuned_decision_tree.joblib']

# %%
y_pred,ACC,PC,RC,FS,AP,roc_auc,gini = print_classification_performance2class_report(tuned_dt_model,valid_data,valid_labels)
# Out:
# Accuracy: 92.00%
# Precision: 65.00%
# Sensitivity (Recall): 38.24%
# Specificity: 97.78%
# Fscore: 48.15%
# Average precision: 30.85%
# G-Mean: 61.15%
# ROC AUC: 82.28%

# %% [markdown]
# <a id="6"></a> <br>
# ## Feature Selection and Retraining Model

# %% [markdown]
# >       Feature Selection

# %% [markdown]
# > Feature selection and feature extraction techniques are used to improve model generalization by reducing the complexity of the model or extracting more informative representations
#
#
# | Feature Selection Techniques   | Characteristics |
# |--------------------------------|-----------------|
# | Variance Threshold            | - This method removes all features whose variance doesn’t meet some threshold. Since the Dorothea dataset is binary, using a variance threshold can help remove features that have little variance and are therefore less informative |
# | Chi-squared (Chi2) (Univariate Feature Selection)          | - Investigate dependence of variables on response<br>- Effective with large datasets |
# | Recursive feature elimination (RFE) | - Searches and ranks features<br>- Actively removes low-ranking features until desired features remain |
# | Principal component analysis (PCA) | - Selects features based on coefficient values<br>- Reduces dimensions of the dataset while maintaining variance between features |

# %%
from sklearn.feature_selection import VarianceThreshold

from sklearn.feature_selection import VarianceThreshold

def select_features_variance_threshold(train_X, valid_X):
    # Calculate the threshold based on the formula provided
    threshold = 0.1 * (0.2 * 0.8)
    
    # Create the VarianceThreshold feature selector
    selector = VarianceThreshold(threshold=threshold)
    
    # Fit the selector on the training dataset and transform both train and valid datasets
    train_X_selected = selector.fit_transform(train_X)
    valid_X_selected = selector.transform(valid_X)
    
    return train_X_selected, valid_X_selected


train_data_new, valid_data_new = select_features_variance_threshold(train_data, valid_data)

# %% [markdown]
# > Testing the Optimized Model on the selected Features

# %%
log_tuned_model_fs = LogisticRegression(C=best_C_log, penalty=best_penalty, solver=best_solver, max_iter=best_max_iter)
log_tuned_model_fs.fit(train_data_new, train_labels)


print("Logistic Model")
y_pred,ACC,PC,RC,FS,AP,roc_auc,gini = print_classification_performance2class_report(log_tuned_model_fs,valid_data_new,valid_labels)
dump(log_tuned_model_fs, 'models/tuned_model_fs/tuned_logistic_regression.joblib')

# %%
tuned_svm_model_fs = SVC(C=best_C_svm, kernel=best_kernel, gamma=best_gamma, probability=True)
tuned_svm_model_fs.fit(train_data_new, train_labels)


print("Support Vector Model")
y_pred,ACC,PC,RC,FS,AP,roc_auc,gini = print_classification_performance2class_report(tuned_svm_model_fs,valid_data_new,valid_labels)
dump(tuned_svm_model_fs, 'models/tuned_model_fs/tuned_support_vector_fs.joblib')

# %%
# Create the Decision Tree model with the best hyperparameters
tuned_dt_model_fs = DecisionTreeClassifier(
    criterion=best_criterion,
    max_depth=best_max_depth,
    min_samples_split=best_min_samples_split,
    min_samples_leaf=best_min_samples_leaf
)

# Train the model using the entire dataset
tuned_dt_model_fs.fit(train_data_new, train_labels)

print("Decision Tree Model")
y_pred,ACC,PC,RC,FS,AP,roc_auc,gini = print_classification_performance2class_report(tuned_dt_model_fs,valid_data_new,valid_labels)
dump(tuned_dt_model_fs, 'models/tuned_model_fs/tuned_decision_tree_fs.joblib')
# Out:
# Decision Tree Model
# Accuracy: 93.14%
# Precision: 75.00%
# Sensitivity (Recall): 44.12%
# Specificity: 98.42%
# Fscore: 55.56%
# Average precision: 38.52%
# G-Mean: 65.89%
# ROC AUC: 80.30%
# ['models/tuned_model_fs/tuned_decision_tree_fs.joblib']
